# %%
name = "zain"

# %%
age = 24

# %%
city = "karachi"

# %%
status = "student"

# %%
print(name)
# Out:
# zain

# %%
print(age)
# Out:
# 24

# %%
print(city)
# Out:
# karachi

# %%
print(status)
# Out:
# student

# %% [markdown]
# # QUESTION 2 -DATA TYPES

# %% [markdown]
# CELL 1 -STRING

# %%
string ="zain"

# %% [markdown]
# cell 2-integer

# %%
integer = 24

# %% [markdown]
# cell 3-float

# %%
float =24.5

# %% [markdown]
# cell_boolean

# %%
boolean = True

# %% [markdown]
# # Question-3 Arithmatic operations
# #1.addition

# %%
num1 = 10
num2 = 3

# %%
print(num1+num2)
# Out:
# 13

# %% [markdown]
# #2.subtraction

# %%
print(num1-num2)
# Out:
# 7

# %% [markdown]
# #3.multiplication

# %%
print(num1*num2)
# Out:
# 30

# %% [markdown]
# #4.division

# %%
print(num1/num2)
# Out:
# 3.3333333333333335

# %% [markdown]
# #5.modulus %

# %%
print(num1%num2)
# Out:
# 1

# %% [markdown]
# #6.power**

# %%
print(num1**num2)
# Out:
# 1000

# %% [markdown]
# #Qustion 4 student marks calculator

# %% [markdown]
# # subject  1

# %%
subject1=75

# %% [markdown]
# #subject 2:

# %%
subject2=80

# %% [markdown]
# #subject 3:

# %%
subject3=70

# %%
total=(subject1+subject2+subject3)

# %%
print(total)
# Out:
# 225

# %% [markdown]
# #average

# %%
average=total/3

# %%
print(average)
# Out:
# 75.0

# %% [markdown]
# #qustion 5 -shopping bills

# %%
price = 500

# %%
quantity = 3

# %%
total_bill =price*quantity

# %%
print(total_bill)
# Out:
# 1500

# %%
length = 10

# %%
width = 5

# %%
area = length * width

# %%
print(area)
# Out:
# 50

# %%
perimeter = 2*(length+width)

# %%
print(perimeter)
# Out:
# 30

# %% [markdown]
# #Question 7 Time _Converter

# %% [markdown]
# # cell 1 _ minutes

# %%
minutes = 250

# %%
hours = minutes // 60

# %%
print(hours)
# Out:
# 4

# %%
remaining_minutes = minutes % 60

# %%
print(remaining_minutes)
# Out:
# 10

# %% [markdown]
# #Question 8_ student Eligibility

# %%
marks = 60

# %%
attendance = 80

# %%
if marks >= 50 and attendance >= 75:
    print("eligible")
else:
    print("not eligible")
# Out:
# eligible

# %% [markdown]
# #Question 9 logical operators

# %%
a =  True

# %%
b = False

# %%
print(a and b)
# Out:
# False

# %%
print (a or b)
# Out:
# True

# %%
print(not a)
# Out:
# False

# %% [markdown]
# # final challange student report

# %%
name = input("name")
# Out:
# name zain

# %%
age = int(input("age"))
# Out:
# age 24

# %%
subject1 = int(input("subject1"))
# Out:
# subject1 75

# %%
subject2 = int(input("subject2"))
# Out:
# subject2 80

# %%
subject3 = int(input("subject3"))
# Out:
# subject3 70

# %%
attendance = int(input("attendance"))
# Out:
# attendance 80

# %%
eligible = (subject1 >= 50 and subject2 >= 50 and subject3 >= 50 and attendance >= 75)

# %%
print(eligible)
# Out:
# True

# %%
print('name',name)
# Out:
# name  zain

# %%
print('age',age)
# Out:
# age 24

# %%
print("total marks",subject1+subject2+subject3)
# Out:
# total marks 225

# %%
print("total average",(subject1+subject2+subject3)/3)
# Out:
# total average 75.0
